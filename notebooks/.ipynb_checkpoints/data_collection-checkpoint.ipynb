# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
import requests
import time

# %%
API_KEY = "AIzaSyDlrOVHZ8stkQCS52a1qf2f06zrvwnVPGw"

# %%
base_url = "https://youtube.googleapis.com/youtube/v3/"
headers = {'Accept': 'application/json'}

# %%
def search(keyword):
    part = "snippet"
    max_results = 50
    res_type = "video"
    
    url = '{0}search?part={1}&maxResults={2}&type={3}&q={4}&key={5}'.format(
        base_url, 
        part,
        max_results, 
        res_type,
        keyword, 
        API_KEY
    )
    
    response = requests.get(url, headers=headers)
    
    if response.status_code == 200:
        return json.loads(response.content.decode('utf-8'))
    else:
        return None

# %%
def get_video_details(videoId):
    
    part = ""
    url = "{0}videos?part={1}".format(base_url)
    
    response = request.get(url, headers=headers)
    
    if response.status_code == 200:
        return json.loads(response.content.decode('utf-8'))
    else:
        return None

# %%
data = search("360 video")

# %%
path = "runs"

if not os.path.exists(path):
    os.makedirs(path)

file = "run_{0}".format(datetime)
filename = '{0}.json'.format(file)

with open(os.path.join(path, filename), 'w') as f:
    json.dump(data, f, ensure_ascii=False)

# %%
def index_videos(filename):
    with open(filename) as json_file:
        data = json.load(json_file)
        
    return data

# %%
data = index_videos(filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-ab380d226669> in <module>
# ----> 1 data = index_videos(filename)
#
# <ipython-input-59-3259d6f7eea9> in index_videos(filename)
#       1 def index_videos(filename):
# ----> 2     with open(filename) as json_file:
#       3         data = json.load(json_file)
#       4
#       5     return data
#
# FileNotFoundError: [Errno 2] No such file or directory: "run_<class 'datetime.datetime'>.json"

# %%
data
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'v1u25QxRSqdsHSXrxrwDxbB1LGA',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'NL',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '-TdXOJRr7gKJgDuhGc80iOB3EiU',
#    'id': {'kind': 'youtube#video', 'videoId': 'hNAbQYU0wpg'},
#    'snippet': {'publishedAt': '2019-12-25T17:15:00Z',
#     'channelId': 'UCnO5ygba3vsJG9IeZLndaTQ',
#     'title': 'VR 360 Video of Top 5 Roller Coaster Rides 4K Virtual Reality',
#     'description': 'VR 360 Videos - Welcome to YouTube VR channel 3D VR 360 I created this 360° video for your amusement. In this video you will experience 5 amazing roller ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hNAbQYU0wpg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hNAbQYU0wpg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': '-TdXOJRr7gKJgDuhGc80iOB3EiU',
#   'id': {'kind': 'youtube#video', 'videoId': 'hNAbQYU0wpg'},
#   'snippet': {'publishedAt': '2019-12-25T17:15:00Z',
#    'channelId': 'UCnO5ygba3vsJG9IeZLndaTQ',
#    'title': 'VR 360 Video of Top 5 Roller Coaster Rides 4K Virtual Reality',
#    'description': 'VR 360 Videos - Welcome to YouTube VR channel 3D VR 360 I created this 360° video for your amusement. In this video you will experience 5 amazing roller ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hNAbQYU0wpg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/hNAbQYU0wpg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/hNAbQYU0wpg/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': '3D-VR-360 VIDEOS',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-12-25T17:15:00Z'}},
# ...
